// %% [markdown]
//   # Problem Set 1

// %% [markdown]
// ## Question 1
// What data type is each of the following?

// %% [markdown]
// 5         Integer
// 5.0       Float
// 5 > 1     Boolean
// '5'       String
// 5 * 2     Integer
// '5' * 2   String
// '5' + '2' String
// 5 / 2     Float
// 5 // 2    Integer
// [5, 2, 1]  List
// 5 in [1, 4, 6] Boolean
// Pi (the number) Float

// %% [markdown]
// ## Question 2
// Write (and evaluate) C# expressions that answer these questions:
//
// a. How many letters are there in 'Supercalifragilisticexpialidocious'?
//
// b. Does 'Supercalifragilisticexpialidocious' contain 'ice' as a substring?
//
// c. Which of the following words is the longest:
//
// Supercalifragilisticexpialidocious, Honorificabilitudinitatibus, or
// Bababadalgharaghtakamminarronnkonn?
//
// d. Which composer comes first in the dictionary: 'Berlioz', 'Borodin', 'Brian',
// 'Bartok', 'Bellini', 'Buxtehude', 'Bernstein'. Which one comes last?

// %%
using System;
using System.Linq;

namespace DataProgrammingAssignment
{
    class Program
    {
        static void Main(string[] args)
        {
             //part A
            // Variable for first string to count number of letters in the string
 
             string i = "Supercalifragilisticexpialidocious";

             Console.WriteLine(i + " contains " + i.Length + " letters\n");
 
            //end of Part A of question 2

            //part B

            //Checking whether First String contains ice as a sub string

                if (i.Contains("ice"))
                    Console.WriteLine(i + " contains ice as a substring\n");

            //END OF Part B of question 2
            //Part C
            //Confirmation of longest string out of the given 3

            string j = "Honorificabilitudinitatibus";

            Console.WriteLine(j + " contains " + j.Length + " letters\n");

            string k = "Bababadalgharaghtakamminarronnkonn";
            Console.WriteLine(k + " contains " + k.Length + " letters\n");


            //Comparison of all 3 strings with an if else nest

            if (i.Length > j.Length)
            {
                if (i.Length > k.Length)
                    Console.WriteLine(i + " is the longest word");
                else if (i.Length < k.Length)
                    Console.WriteLine(k + " is the longest word");
                else
                    Console.WriteLine("Both " + i + " and " + k + " are of equal length and longest words");
            }
            else if (i.Length < j.Length)
            {
                if (j.Length > k.Length)
                    Console.WriteLine(j + " is the longest word");
                else if (j.Length < k.Length)
                    Console.WriteLine(k + " is the longest word");
                else
                    Console.WriteLine("Both " + j + " and " + k + " are of equal length and longest words");
            }
            else
            {
                if (i.Length > k.Length)
                    Console.WriteLine("Both " + i + " and " + j + " are of equal length and longest words");
                else if (i.Length < k.Length)
                    Console.WriteLine(k + " is the longest word");
                else
                    Console.WriteLine("All " + i + ", " + j + ", and" + k + " have the same length");
            }

            //END OF Part c of question 2
            
            //part D    

            //using an array to sort and select first and last words as if they were in a dictionary

            string[] stringArrayUnsorted = new string[]
                {
                    "Berlioz",
                    "Borodin",
                    "Brian",
                    "Bartok",
                    "Bellini",
                    "Buxtehude",
                    "Bernstein"
                };

            int length = stringArrayUnsorted.Length;

            //using var to collect and sort all the strings stored in unsorted array
            var sortedArray = from a in stringArrayUnsorted
                              orderby a
                              select a;

            Console.WriteLine(sortedArray.First());
            Console.WriteLine(sortedArray.Last());

            ////END OF Part d of question 2
            Console.ReadLine();
        }
    }
}
// Out:
// (4,1): error CS7021: Cannot declare namespace in script code

// %% [markdown]
// ![Q2C#output.PNG](attachment:Q2C#output.PNG)

// %% [markdown]
// ## Question 3
//
// Implement function triangleArea(a,b,c) that takes as input the lengths of the 3
// sides of a triangle and returns the area of the triangle. By Heron's formula, the area
// of a triangle with side lengths a, b, and c is
//
// s(s - a)(s -b)(s -c)
//
// , where    s = (a+b+c)/2.
//
// triangleArea(2,2,2)
//
// 1.7320508075688772

// %%
using System;

namespace Dataprogramming_Question3
{
    class Program
    {
        static void Main(string[] args)
        {
            double s, x, y, z, area;

            Console.WriteLine("Enter the values of sides of triangle x, y, z \n");
            x = Convert.ToDouble(Console.ReadLine());
            y = Convert.ToDouble(Console.ReadLine());
            z = Convert.ToDouble(Console.ReadLine());

            s = (x + y + z) / 2;

            area = Math.Sqrt(s * (s - x) * (s - y) * (s - z));

            Console.WriteLine("Area of triangle is " + area);
            Console.ReadLine();

        }
    }
    }
// Out:
// (3,1): error CS7021: Cannot declare namespace in script code

// %% [markdown]
// ![Q3C#output.PNG](attachment:Q3C#output.PNG)

// %% [markdown]
// ## Question 4
//
// Write a program in C# Sharp to separate odd and even integers in separate arrays.
// Go to the editor
//
// Test Data :
// Input the number of elements to be stored in the array :5
//
// Input 5 elements in the array :
//
// element - 0 : 25
//
// element - 1 : 47
//
// element - 2 : 42
//
// element - 3 : 56
//
// element - 4 : 32
//
// Expected Output:
//
// The Even elements are:
//
// 42 56 32
//
// The Odd elements are :
//
// 25 47

// %%
using System;

namespace PS1_Q4
{
    class Program
    {
        static void Main(string[] args)
        {
            Console.WriteLine("Hello World!");

            int[] collector = new int[10];
            int[] evenArray = new int[10];
            int[] oddArray = new int[10];
            int x, y = 0, z = 0, i;


            Console.Write("Input the number of elements to be stored in the array :");
            i = Convert.ToInt32(Console.ReadLine());

            Console.Write("Input {0} elements in the array :\n", i);
            for (x = 0; x < i; x++)
            {
                Console.Write("element - {0} : ", x);
                collector[x] = Convert.ToInt32(Console.ReadLine());
            }

            for (x = 0; x < i; x++)
            {
                if (collector[x] % 2 == 0)
                {
                    evenArray[y] = collector[x];
                    y++;
                }
                else
                {
                    oddArray[z] = collector[x];
                    z++;
                }
            }

            Console.Write("\nThe Even elements are : \n");
            for (x = 0; x < y; x++)
            {
                Console.Write("{0} ", evenArray[x]);
            }

            Console.Write("\nThe Odd elements are :\n");
            for (x = 0; x < z; x++)
            {
                Console.Write("{0} ", oddArray[x]);
            }
            Console.ReadLine();

        }
    }
}
// Out:
// (3,1): error CS7021: Cannot declare namespace in script code

// %% [markdown]
// ![Q4C#output.PNG](attachment:Q4C#output.PNG)

// %% [markdown]
// ## Question 5
//
//
//     a. Write a function inside(x,y,x1,y1,x2,y2) that returns True or False
// depending on whether the point (x,y) lies in the rectangle with lower left
// corner (x1,y1) and upper right corner (x2,y2).
//  inside(1,1,0,0,2,3)
// True
//
//  inside(-1,-1,0,0,2,3)
// False
//
// b. Use function inside() from part a. to write an expression that tests whether
// the point (1,1) lies in both of the following rectangles: one with lower left
// corner (0.3, 0.5) and upper right corner (1.1, 0.7) and the other with lower
// left corner (0.5, 0.2) and upper right corner (1.1, 2).

// %%
using System;

namespace PS1_Q5
{
    class Program
    {
        static void Main(string[] args)
        {
           
            Double x, x1, x2, y, y1, y2;

            Console.WriteLine("Input the point you want to find and the lower left and upper right corner of the rectangle \n");
             x = Convert.ToDouble(Console.ReadLine());
             y = Convert.ToDouble(Console.ReadLine());
             x1 = Convert.ToDouble(Console.ReadLine());
             y1 = Convert.ToDouble(Console.ReadLine());
             x2 = Convert.ToDouble(Console.ReadLine());
             y2 = Convert.ToDouble(Console.ReadLine());

             Inside(x, y, x1, y1, x2, y2);
             Console.ReadLine();  
        }

        static void Inside(Double p, Double q, Double p1, Double q1, Double p2, Double q2)

        {

            if (p > p1 && p < p2 && q > q1 && q < q2)
                Console.WriteLine("True");
            else
                Console.WriteLine("false");
        }

    }
}

// %% [markdown]
// ![Q5#output_true.PNG](attachment:Q5#output_true.PNG)

// %% [markdown]
// ![Q5#output_false.PNG](attachment:Q5#output_false.PNG)

// %% [markdown]
// ![Q5#output_B_false.PNG](attachment:Q5#output_B_false.PNG)

// %% [markdown]
// ![Q5#output_B_true.PNG](attachment:Q5#output_B_true.PNG)
